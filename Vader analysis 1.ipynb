# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
import pandas as pd
import numpy as np

# %%
# Sample Strings
file = "Tweet_Dump.csv"
df = pd.read_csv(file, encoding = "latin-1")
# Target String Setting
df.head()
# Out:
#    Unnamed: 0    state                                               text  \
# 0           0  Alabama  The last visits -----&gt; https://t.co/iVCRNsA5wR
# 1           1  Alabama  RT @GDouglasJones: I dont think thats the f...
# 2           2  Alabama  RT @YouLove_Ebony: I salute everybody thats ou...
# 3           3  Alabama  We just not on the same level no more and that...
# 4           4  Alabama  RT @UWA_Softball: Our own Bree Thompson singin...
#
#          lat        lon  followers  favorites  friends  statuses_count  \
# 0  32.886361 -86.813639       1103       1624     1049            1014
# 1  32.886361 -86.813639       1423     334377     1539          166036
# 2  32.886361 -86.813639       1664       2997      571          108941
# 3  32.886361 -86.813639        442        261      554           11537
# 4  32.886361 -86.813639        243        325      243            1286
#
#    compound  pos  neg
# 0       NaN  NaN  NaN
# 1       NaN  NaN  NaN
# 2       NaN  NaN  NaN
# ...

# %%
# Run analysis
for index, row in df.iterrows():
    compound = analyzer.polarity_scores(row["text"])["compound"]
    pos = analyzer.polarity_scores(row["text"])["pos"]
    #neu = analyzer.polarity_scores(target_string)["neu"]
    neg = analyzer.polarity_scores(row["text"])["neg"]
    df.set_value(index, "pos", pos)
    df.set_value(index, "neg", neg)
    df.set_value(index, "compound", compound)


# Print Analysis
df.head(50)
# Out:
#     Unnamed: 0    state                                               text  \
# 0            0  Alabama  The last visits -----&gt; https://t.co/iVCRNsA5wR
# 1            1  Alabama  RT @GDouglasJones: I dont think thats the f...
# 2            2  Alabama  RT @YouLove_Ebony: I salute everybody thats ou...
# 3            3  Alabama  We just not on the same level no more and that...
# 4            4  Alabama  RT @UWA_Softball: Our own Bree Thompson singin...
# 5            5  Alabama  I will say this. I think I have a stunningly b...
# 6            6  Alabama  RT @CalebHorton5: I'm very blessed and I want ...
# 7            7  Alabama  I added a video to a @YouTube playlist https:/...
# 8            8  Alabama  RT @HailStateMKTG: Celebrate #MaroonFriday tom...
# 9            9  Alabama                       Halftime: Lee 29, Carver 20.
# 10          10  Alabama  RT @occdissent: I'm not interested in oppressi...
# ...

# %%
df.to_csv("Vader1.csv")
