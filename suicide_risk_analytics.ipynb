# %%
import pandas as pd
import numpy as np


Zipcode_States_With_Geo_Cordinates = "Zipcode_States_With_Geo_Cordinates.csv"
Suicide_Risk_Analytics_Expressions = "Suicide_Risk_Analytics_Expressions.csv"

suicide_belt_data = pd.read_csv(Zipcode_States_With_Geo_Cordinates)
expressions_data = pd.read_csv(Suicide_Risk_Analytics_Expressions)

# %%
expressions_data.head()
# Out:
#                                        Expression  \
# 0                          With one's last breath
# 1                            Wiped out...way up..
# 2  Wearing a pine overcoat (i.e. a wooden coffin)
# 3                                      Up and die
# 4                           Until one's dying day
#
#                                           Definition      Context  \
# 0                                    Before one dies     Literary
# 1           Dead usually if multiple individuals die      Neutral
# 2                                               Dead        Slang
# 3  To die usually before doing some sort of impor...  Euphemistic
# 4                               As long as one lives      Neutral
#
#                                              Remarks
# 0                                                NaN
# 1                                                NaN
# 2  Idiom used by American gangsters of the early ...
# ...

# %%
suicide_belt_data.head()
# Out:
#    Zip Code Place Name   State State Abreviation                  County  \
# 0     99501  Anchorage  Alaska                AK  Anchorage Municipality
# 1     99502  Anchorage  Alaska                AK  Anchorage Municipality
# 2     99503  Anchorage  Alaska                AK  Anchorage Municipality
# 3     99504  Anchorage  Alaska                AK  Anchorage Municipality
# 4     99505       Jber  Alaska                AK  Anchorage Municipality
#
#    Latitude  Longitude Suicide Belt State
# 0   61.2116  -149.8761                Yes
# 1   61.1661  -149.9600                Yes
# 2   61.1900  -149.8938                Yes
# 3   61.2037  -149.7447                Yes
# 4   59.8666  -158.5996                Yes
